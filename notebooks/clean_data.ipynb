# %% [markdown]
# # 数据清洗示例
# 本 notebook 演示如何运行 scripts/data_cleaning.py，并快速查看清洗结果。
# 步骤：
# 1. 在项目根目录运行 `python scripts/data_cleaning.py`（或在 notebook 中运行下面的命令）
# 2. 在 data/cleaned/ 中查看输出文件

# %%
# 在 notebook 中运行清洗脚本
import os
os.system('python scripts\data_cleaning.py')

# %%
# 显示清洗后示例（前5行）
import pandas as pd
fn = 'data\cleaned\sz000001.csv'
if os.path.exists(fn):
    df = pd.read_csv(fn, parse_dates=[0], index_col=0)
    display(df.head())
else:
    print('清洗文件未找到：', fn)
