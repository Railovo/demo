# %% [markdown]
# # 多因子研究（沪深300 池）报告
# 本 notebook 汇总了因子定义、IC 分析与分组回测结果；所有脚本与数据位于仓库根目录。

# %% [markdown]
# ## 关键图表（输出文件）
# - outputs/filtered_ic_rolling.png  （IC 滚动均值）
# - outputs/filtered_quintile_cum_returns.png  （五分组累计收益）

# %%
from IPython.display import Image, display
display(Image('..\outputs\filtered_ic_rolling.png'))
display(Image('..\outputs\filtered_quintile_cum_returns.png'))

# %% [markdown]
# ## 结论摘要
# - 中期动量（m120）在筛选池上展现稳定正 IC；短中期（m60）为弱正。
# - vol/size 因子 IC 为负，提示小盘或低波动存在溢价（需行业/市值中性验证）。
# - 建议下一步：构建多因子组合、加入行业中性与交易成本，并准备项目报告页。
