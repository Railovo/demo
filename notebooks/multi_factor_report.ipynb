# %% [markdown]
# # Multi-factor Portfolio Report
# Includes factor definitions, construction, IC analysis, and multi-factor backtest results.

# %%
from IPython.display import Image, display
display(Image('../outputs/filtered_ic_rolling.png'))
display(Image('../outputs/filtered_quintile_cum_returns.png'))
display(Image('../outputs/multi_factor_cum.png'))

# %% [markdown]
# ## How to reproduce
# Run scripts in order: download_hs300_akshare.py -> data_cleaning.py -> filter_pool.py -> run_filtered_analysis.py -> scripts/multi_factor_portfolio.py
