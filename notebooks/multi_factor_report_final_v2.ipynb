# %% [markdown]
# # Multi-factor Portfolio Final Report (v2)
# Consolidated results: factor definitions, IC analysis, robustness tests, and final recommendations for interview demonstration.

# %% [markdown]
# ## Key visuals
# - IC rolling mean: outputs/highres_filtered_ic_rolling.png
# - IC significance (p-values): outputs/stat_ic_pvalues.png
# - Quintile cumulative returns: outputs/highres_filtered_quintile_cum_returns.png
# - Multi-factor NAV: outputs/highres_multi_factor_cum.png
# - Backtest Sharpe bootstrap: outputs/backtest_sharpe_bootstrap.png
# - Robustness heatmaps: outputs/robustness_heatmap_cost_600bps.png, outputs/robustness_heatmap_cost_1200bps.png

# %%
from IPython.display import Image, display
display(Image('../outputs/highres_filtered_ic_rolling.png'))
display(Image('../outputs/stat_ic_pvalues.png'))
display(Image('../outputs/highres_filtered_quintile_cum_returns.png'))
display(Image('../outputs/highres_multi_factor_cum.png'))
display(Image('../outputs/backtest_sharpe_bootstrap.png'))
display(Image('../outputs/robustness_heatmap_cost_600bps.png'))
display(Image('../outputs/robustness_heatmap_cost_1200bps.png'))

# %%
import pandas as pd
print('Multi-factor summary:')
display(pd.read_csv('../outputs/multi_factor_summary.csv', index_col=0, header=None).T)
print('\nRobustness param summary:')
display(pd.read_csv('../outputs/robustness_param_summary.csv').head())

# %% [markdown]
# ## Short conclusions
# - After industry neutralization, factor exposures change materially; robustness tests indicate momo window=120 with long_pct=0.2 is robust across costs.
# - Next: refine industry-neutral regression, add liquidity-aware execution, and create 1-page slide for interview.
